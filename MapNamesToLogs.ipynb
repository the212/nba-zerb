# %%
ls
# Out:
# MapNamesToLogs.ipynb  cleanGameLogs.py      gameLogs.ipynb        mapNames.py           players/
# bball-ref.js          finalGameLog.py       includes/             node_modules/

# %%
import pandas as pd
import numpy as np

#pd.set_option('display.max_columns', 500)

logs = 'players/2015/gamelogsd.csv'
names = 'players/2015/namesd.csv'

gamesd = pd.read_csv(logs)
namesd = pd.read_csv(names)

# %%
gamesd
# Out:
#       Rk   G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  \
# 0      1   1  2014-10-29  33-172  NYK        NaN  CHI    L (-24)   1  19:51
# 1      2   2  2014-10-30  33-173  NYK          @  CLE     W (+5)   1   5:34
# 2      3   3  2014-11-02  33-176  NYK        NaN  CHO     W (+3)   1  22:21
# 3      4   4  2014-11-04  33-178  NYK        NaN  WAS    L (-15)   1  20:12
# 4      5   5  2014-11-05  33-179  NYK          @  DET     L (-3)   1  14:30
# 5      6   6  2014-11-07  33-181  NYK          @  BRK    L (-11)   1   4:52
# 6      7   7  2014-11-08  33-182  NYK          @  ATL     L (-7)   1  24:46
# 7      8   8  2014-11-10  33-184  NYK        NaN  ATL     L (-6)   1  16:05
# 8      9   9  2014-11-12  33-186  NYK        NaN  ORL     L (-2)   1  27:24
# 9     10  10  2014-11-14  33-188  NYK        NaN  UTA     L (-2)   1  18:19
# 10    11  11  2014-11-16  33-190  NYK        NaN  DEN    W (+16)   1  22:08
# ...

# %%
namesd
# Out:
#           Player  From    To  Pos    Ht   Wt       Birth Date  \
# 0  Anthony Davis  2013  2016  F-C  6-10  253    March 11 1993
# 1       Ed Davis  2011  2016    F  6-10  240      June 5 1989
# 2     Glen Davis  2008  2015    F   6-9  289   January 1 1986
# 3    Austin Daye  2010  2015    F  6-11  220      June 5 1988
# 4      Luol Deng  2005  2016    F   6-9  220    April 16 1985
# 5     Boris Diaw  2004  2016  F-C   6-8  250    April 16 1982
# 6   Gorgui Dieng  2014  2016    C  6-11  241  January 18 1990
# 7     Larry Drew  2015  2015    G   6-2  180     March 5 1990
#
#                                 College      pname
# 0                University of Kentucky  davisan02
# 1          University of North Carolina  davised01
# 2            Louisiana State University  davisgl01
# 3                    Gonzaga University   dayeau01
# 4                       Duke University   denglu01
# 5                                   NaN   diawbo01
# ...

# %%
#gamesNames = pd.concat([gamesd, namesd])

# %%
#gamesNames

# %%
#gamesd = gamesd.append(namesd)

# %%
#gamesNames = pd.concat([gamesd, namesd], axis=1)

# %%
#gamesd
