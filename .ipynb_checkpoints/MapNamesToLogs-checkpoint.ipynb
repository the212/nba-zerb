# %%
ls
# Out:
# MapNamesToLogs.ipynb  bball-ref.js          finalGameLog.py       gameLogs.ipynb        mapNames.py           players/
# README.md*            cleanGameLogs.py      finalNames.py         includes/             node_modules/

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

n = 'players/2015/names/allnames.csv'
names = pd.read_csv(n)

g = 'players/2015/logs/alllogs.csv'
games = pd.read_csv(g)

# %%
games
# Out:
#        Rk   G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  \
# 0       1   1  2014-10-29  24-023  NYK        NaN  CHI    L (-24)   0  21:28
# 1       2   2  2014-10-30  24-024  NYK          @  CLE     W (+5)   1  22:27
# 2       3   3  2014-11-02  24-027  NYK        NaN  CHO     W (+3)   1  20:20
# 3       5   4  2014-11-05  24-030  NYK          @  DET     L (-3)   0  13:42
# 4       6   5  2014-11-07  24-032  NYK          @  BRK    L (-11)   0  22:14
# 5       7   6  2014-11-08  24-033  NYK          @  ATL     L (-7)   0  13:34
# 6       9   7  2014-11-12  24-037  NYK        NaN  ORL     L (-2)   1  20:12
# 7      10   8  2014-11-14  24-039  NYK        NaN  UTA     L (-2)   0  19:39
# 8      11   9  2014-11-16  24-041  NYK        NaN  DEN    W (+16)   1  31:10
# 9      13  10  2014-11-19  24-044  NYK          @  MIN    L (-16)   1  32:18
# 10     14  11  2014-11-22  24-047  NYK        NaN  PHI     W (+8)   1  23:57
# ...

# %%
#gamesNames = pd.concat([gamesd, namesd])

# %%
#gamesNames

# %%
#gamesd = gamesd.append(namesd)

# %%
#gamesNames = pd.concat([gamesd, namesd], axis=1)

# %%
#gamesd

# %%
result = pd.concat([games, names], axis=1, join_axes=[games.index])

# %%
result
# Out:
#        Rk   G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  \
# 0       1   1  2014-10-29  24-023  NYK        NaN  CHI    L (-24)   0  21:28
# 1       2   2  2014-10-30  24-024  NYK          @  CLE     W (+5)   1  22:27
# 2       3   3  2014-11-02  24-027  NYK        NaN  CHO     W (+3)   1  20:20
# 3       5   4  2014-11-05  24-030  NYK          @  DET     L (-3)   0  13:42
# 4       6   5  2014-11-07  24-032  NYK          @  BRK    L (-11)   0  22:14
# 5       7   6  2014-11-08  24-033  NYK          @  ATL     L (-7)   0  13:34
# 6       9   7  2014-11-12  24-037  NYK        NaN  ORL     L (-2)   1  20:12
# 7      10   8  2014-11-14  24-039  NYK        NaN  UTA     L (-2)   0  19:39
# 8      11   9  2014-11-16  24-041  NYK        NaN  DEN    W (+16)   1  31:10
# 9      13  10  2014-11-19  24-044  NYK          @  MIN    L (-16)   1  32:18
# 10     14  11  2014-11-22  24-047  NYK        NaN  PHI     W (+8)   1  23:57
# ...
